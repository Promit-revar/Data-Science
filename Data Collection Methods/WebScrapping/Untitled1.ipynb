# %%
import requests
from bs4 import BeautifulSoup

# %%
data=requests.get("https://iko.chameleonpower.com/#roomscenes")
strn=data.text

# %%
html=BeautifulSoup(strn,"html.parser")
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ab" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="width=device-width,minimum-scale=1.0,maximum-scale=1.0,initial-scale=1.0" name="viewport"/>
#   <meta content="Check out this design I made using the IKO - Roof Viewer Visualizer!" property="og:title"/>
#   <meta content="visualizer/img/landing.png" property="og:image"/>
#   <meta content="tx12dhsu8apmvi932kdpkvqvgowa5d" name="facebook-domain-verification"/>
#   <title>
#    IKO - Roof Viewer
#   </title>
#   <!-- Google Tag Manager -->
#   <script>
#    (function (w, d, s, l, i) {
#   w[l] = w[l] || []; w[l].push({
#     'gtm.start':
#       new Date().getTime(), event: 'gtm.js'
#   }); var f = d.getElementsByTagName(s)[0],
#     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#       'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#   })(window, document, 'script', 'dataLayer', 'GTM-WPRZSPQ');
# ...

# %%
m= "https://renderfarm2.chameleonpower.com/proxy/getImage.ashx?spec=IKO\ "
m=m.strip()

# %%
#https://renderfarm2.chameleonpower.com/proxy/getImage.ashx?spec=IKO\New_Exteriors\Exterior_43&type=base&size=600
#https://renderfarm2.chameleonpower.com/proxy/getImage.ashx?spec=IKO\New_Exteriors\Exterior_41&type=base&size=600
#https://renderfarm2.chameleonpower.com/proxy/getImage.ashx?spec=IKO\New_Exteriors\Exterior_42&type=base&size=600
for i in range(1,44):
    s= f'D:\Data Science\homepics\img{i}.jpg'
    n= f"New_Exteriors\Exterior_{i}&type=base&size=600"
    l=m+n
    #print(s)
    img=requests.get(l)
    with open(s,'wb') as f:
        f.write(img.content)

# %%
print(n)
# Out:
# New_Exteriors\Exterior_7&type=base&size=600
