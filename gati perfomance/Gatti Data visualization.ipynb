# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Kiran Rever grade sheet-2020-21 - Sheet1.csv")
df.head()
# Out:
#    Sr No           Student's Full Name  School GrSec       Gr  Sec  \
# 0    894          Ajit Pravin Mokariya  Metoda   NaN  GRADE 4  NaN
# 1    895       Ashishkumar Arun Mandal  Metoda   NaN  GRADE 4  NaN
# 2    896  Ayushi Kamleshbhai Kantariya  Metoda   NaN  GRADE 4  NaN
# 3    897      Daksh Pradipbhai Solanki  Metoda   NaN  GRADE 4  NaN
# 4    898  Khushali Prafulbhai Sangecha  Metoda   NaN  GRADE 4  NaN
#
#            Slot timings      Day New Category Teacher Name  ...   Activity-2  \
# 0  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 1  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 2  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 3  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 4  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
#
#   Marks.1 Activity-3 Marks.2       Activity-4 Marks.3 Activity-5 Marks.4  \
# ...

# %%
def clean(i):
    if(i=='NT'):
        i=0.0
  
    return i

# %%
def fill(i):
    if(i==0.0):
        i=np.mean(df['Marks2'])
        #print(i)
   
    return i

# %%
df.columns=['SNo', "Name", 'School', 'GrSec', 'Gr', 'Sec',
       'Slot timings', 'Day', 'New Category', 'TName', 'Activity1',
       'Marks', 'Activity2', 'Marks1', 'Activity3', 'Marks2', 'Activity4',
       'Marks3', 'Activity5', 'Marks4', 'Activity6', 'Marks5']



#df['Marks2']=df['Marks2'].dropna(inplace=True)


df['Marks2']=df['Marks2'].apply(clean)
print(df['Marks2'].isnull().sum())
df['Marks2'].astype('float')


df['Marks2']=df['Marks2'].astype("float")
np.mean(df['Marks2'])
# Out:
# 28
# 19.92606595253098

# %%
df.head()
# Out:
#    SNo                          Name  School GrSec       Gr  Sec  \
# 0  894          Ajit Pravin Mokariya  Metoda   NaN  GRADE 4  NaN
# 1  895       Ashishkumar Arun Mandal  Metoda   NaN  GRADE 4  NaN
# 2  896  Ayushi Kamleshbhai Kantariya  Metoda   NaN  GRADE 4  NaN
# 3  897      Daksh Pradipbhai Solanki  Metoda   NaN  GRADE 4  NaN
# 4  898  Khushali Prafulbhai Sangecha  Metoda   NaN  GRADE 4  NaN
#
#            Slot timings      Day New Category        TName  ...    Activity2  \
# 0  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 1  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 2  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 3  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
# 4  Slot 1 (7.30-9.10am)  Tuesday          NaN  Kiran Rever  ...  Paper Craft
#
#   Marks1 Activity3 Marks2        Activity4  Marks3 Activity5 Marks4 Activity6  \
# ...

# %%
df['Marks2']=df['Marks2'].apply(fill)
df['Marks2'].fillna(0,inplace=True)
for i in df['Marks2']:
    print(type(i),i)
# Out:
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 20.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 24.0
# <class 'float'> 17.0
# <class 'float'> 18.0
# <class 'float'> 16.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 18.0
# <class 'float'> 0.0
# <class 'float'> 25.0
# <class 'float'> 0.0
# <class 'float'> 22.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 20.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 0.0
# <class 'float'> 22.0
# <class 'float'> 16.0
# <class 'float'> 0.0
# <class 'float'> 23.0
# <class 'float'> 16.0
# <class 'float'> 25.0
# <class 'float'> 20.0
# <class 'float'> 16.0
# <class 'float'> 16.0
# <class 'float'> 18.0
# <class 'float'> 20.0
# <class 'float'> 18.0
# <class 'float'> 25.0
# <class 'float'> 18.0
# <class 'float'> 25.0
# <class 'float'> 24.0
# ...

# %%
marks2=list(df['Marks2'])
Names=list(df['Name'])
plt.figure(figsize=(15,30))
plt.barh(Names,marks2)
plt.show()

# %%
from collections import Counter
marks2
a=[]


for i in range(len(marks2)):
    if(marks2[i]>20):
        a.append(">20")
    elif(marks2[i]>15):
        a.append(">15")
    elif(marks2[i]>0 and marks2[i]<=10):
        a.append("<11")
    elif(marks2[i]==0):
        a.append("Not attemped")
    
x=Counter(a)
#
labels=list(x.keys())
cols=['#ff0013','#ffd044','#12ff13','#a023fd']
plt.figure(figsize=(15,12))
plt.pie(list(x.values()),labels=labels,wedgeprops={'edgecolor':'yellow'},explode=[0,0,0],colors=cols,shadow='True',startangle=90,autopct='%1.1f%%')
plt.title("Marks PieChart",color='#ff0000')
plt.show()
