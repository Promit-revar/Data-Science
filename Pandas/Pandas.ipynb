# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Seires:
# Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called index.

# %%
data=np.random.randint(0,10,5)
s=pd.Series(data)
print(data)
s
# Out:
# [8 9 5 6 3]
# 0    8
# 1    9
# 2    5
# 3    6
# 4    3
# dtype: int32

# %%
si=pd.Series(data,index=["i","ii","iii","iv","v"])
si
# Out:
# i      8
# ii     9
# iii    5
# iv     6
# v      3
# dtype: int32

# %%
data2={"mast":1,"masti":2,"mastii":3}
sd=pd.Series(data2)
sd
# Out:
# mast      1
# masti     2
# mastii    3
# dtype: int64

# %% [markdown]
# Accessing Data:

# %%
print(s[0],si['ii'],sd["masti"])
# Out:
# 8 9 2

# %% [markdown]
# Data Frame:
#     A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# Features of DataFrame
# Potentially columns are of different types
# Size – Mutable
# Labeled axes (rows and columns)
# Can Perform Arithmetic operations on rows and columns
# Structure
# Let us assume that we are creating a data frame with student’s data.
# ![structure_table.jpg](attachment:structure_table.jpg)
#
# Structure Table
# You can think of it as an SQL table or a spreadsheet data representation.

# %%
data=np.random.randint(0,10,(3,2))
data
# Out:
# array([[9, 8],
#        [4, 6],
#        [4, 3]])

# %%
df=pd.DataFrame(data)
df
# Out:
#    0  1
# 0  9  8
# 1  4  6
# 2  4  3

# %%
data2=[["Alex",12],["Balgam",15],["dan",17]]
df1=pd.DataFrame(data2,index=["emp1","emp2","emp3"],columns=["Name","Age"],dtype=float)
df1
# Out:
#         Name   Age
# emp1    Alex  12.0
# emp2  Balgam  15.0
# emp3     dan  17.0

# %%
data3={"Name":["Tom","Jerry"],"Age":[23,20]}
df2=pd.DataFrame(data3)
df2
# Out:
#     Name  Age
# 0    Tom   23
# 1  Jerry   20

# %% [markdown]
# Accessing Data:

# %%
print(df[0])
# Out:
# 0    9
# 1    4
# 2    4
# Name: 0, dtype: int32

# %%
print(df1.loc["emp1"]) #loc selects row when index is passed (defined index)
# Out:
# Name    Alex
# Age       12
# Name: emp1, dtype: object

# %%
print(df1.iloc[1]) #iloc is used to index rows with integer even though the index is diffrent
# Out:
# Name    Balgam
# Age         15
# Name: emp2, dtype: object

# %%
df1.loc["emp1"]["Name"]
# Out:
# 'Alex'

# %%
print(df1)
dfa = pd.DataFrame([["Raj",23]],index=["emp4"],columns = ['Name','Age'])

df1 = df1.append(dfa)
df1
# Out:
#         Name   Age
# emp1    Alex  12.0
# emp2  Balgam  15.0
# emp3     dan  17.0
#         Name   Age
# emp1    Alex  12.0
# emp2  Balgam  15.0
# emp3     dan  17.0
# emp4     Raj  23.0

# %% [markdown]
# Deletion of Rows
# Use index label to delete or drop rows from a DataFrame. If label is duplicated, then multiple rows will be dropped.

# %%
print(df1)
df1=df1.drop("emp1")
df1
# Out:
#         Name   Age
# emp1    Alex  12.0
# emp2  Balgam  15.0
# emp3     dan  17.0
# emp4     Raj  23.0
#         Name   Age
# emp2  Balgam  15.0
# emp3     dan  17.0
# emp4     Raj  23.0

# %%
df=pd.DataFrame(np.identity(3),index=["a","b","c"],columns=["x","y","z"],dtype=int)
df
# Out:
#    x  y  z
# a  1  0  0
# b  0  1  0
# c  0  0  1

# %%
df.values.reshape(1,9)
# Out:
# array([[1, 0, 0, 0, 1, 0, 0, 0, 1]])

# %%
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}
df=pd.DataFrame(d)
df
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65

# %% [markdown]
# <ul><b>sum()</b>
# <li>Returns the sum of the values for the requested axis. By default, axis is index (axis=0).</li></ul>

# %%
df.sum()
# Out:
# Name      TomJamesRickyVinSteveSmithJackLeeDavidGasperBe...
# Age                                                     382
# Rating                                                44.92
# dtype: object

# %%
df["Age"].sum()
# Out:
# 382

# %% [markdown]
# <ul><b>mean()</b>
# <li>Returns the average value</li></ul>

# %%
df.mean()
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %% [markdown]
# <ul><b>std()</b>
# <li>Returns the Bressel standard deviation of the numerical columns.</li></ul>

# %%
df.std()
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %% [markdown]
# Functions & Description
# Let us now understand the functions under Descriptive Statistics in Python Pandas. The following table list down the important functions −
# <table>
#     <tr>
#     <th>
#         Sr.No.</th><th>	Function</th><th>Description</th></tr>
#     <td>1</td><td>	count()	</td><td>Number of non-null observations</td></tr>
# <tr><td>2</td><td>	sum()</td><td>	Sum of values</td></tr>
# <tr><td>3</td><td>	mean()</td><td>	Mean of Values</td></tr>
# <tr><td>4</td><td>	median()</td><td>	Median of Values</td></tr>
# <tr><td>5</td><td>	mode()	</td><td>Mode of values</td></tr>
# <tr><td>6</td><td>	std()</td><td>	Standard Deviation of the Values</td></tr>
# <tr><td>7</td><td>	min()</td><td>	Minimum Value</td></tr>
# <tr><td>8</td><td>	max()</td><td>	Maximum Value</td></tr>
# <tr><td>9</td><td>	abs()</td><td>	Absolute Value</td></tr>
# <tr><td>10	</td><td>prod()	</td><td>Product of Values</td></tr>
# <tr><td>11</td><td>	cumsum()</td><td>Cumulative Sum</td></tr>
# <tr><td>12	</td><td>cumprod()</td><td>	Cumulative Product</td></tr>
# </table>
# Note − Since DataFrame is a Heterogeneous data structure. Generic operations don’t work with all functions.
#
# Functions like <b>sum(), cumsum()</b> work with both numeric and character (or) string data elements without any error. Though n practice, character aggregations are never used generally, these functions do not throw any exception.
#
# Functions like<b> abs(), cumprod()</b> throw exception when the DataFrame contains character or string data because such operations cannot be performed.
#
# Summarizing Data
# The <b>describe()</b> function computes a summary of statistics pertaining to the DataFrame columns.

# %%
df.describe()
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %% [markdown]
# This function gives the mean, std and IQR values. And, function excludes the character columns and given summary about numeric columns. 'include' is the argument which is used to pass necessary information regarding what columns need to be considered for summarizing. <b>Takes the list of values; by default, 'number'.</b>
#
# <b>object </b>− Summarizes String columns<br>
# <b>number</b> − Summarizes Numeric columns<br>
# <b>all</b> − Summarizes all columns together (Should not pass it as a list value)

# %%
df.describe(include=['object'])
# Out:
#          Name
# count      12
# unique     12
# top     James
# freq        1

# %%
df.describe(include='all')
# Out:
#          Name        Age     Rating
# count      12  12.000000  12.000000
# unique     12        NaN        NaN
# top     James        NaN        NaN
# freq        1        NaN        NaN
# mean      NaN  31.833333   3.743333
# std       NaN   9.232682   0.661628
# min       NaN  23.000000   2.560000
# 25%       NaN  25.000000   3.230000
# 50%       NaN  29.500000   3.790000
# 75%       NaN  35.500000   4.132500
# max       NaN  51.000000   4.800000

# %% [markdown]
# To apply your own or another library’s functions to Pandas objects, you should be aware of the three important methods. The methods have been discussed below. The appropriate method to use depends on whether your function expects to operate on an entire DataFrame, row- or column-wise, or element wise.
# <ul>
# <li>Table wise Function Application: pipe()<br></li>
# <li>Row or Column Wise Function Application: apply()<br></li>
# <li>Element wise Function Application: applymap()</li></ul>
# <h1>Table-wise Function Application</h1>
# Custom operations can be performed by passing the function and the appropriate number of parameters as pipe arguments. Thus, operation is performed on the whole DataFrame.

# %%
def add(a,b):
    return a+b

# %%
df=pd.DataFrame(np.identity(3,dtype=int))

df2=pd.DataFrame(np.random.randint(1,10,(3,3)))
print(df)
df2
# Out:
#    0  1  2
# 0  1  0  0
# 1  0  1  0
# 2  0  0  1
#    0  1  2
# 0  6  2  2
# 1  9  4  1
# 2  2  6  4

# %%
df=df.pipe(add,df2) # adding matrices ...
df
# Out:
#    0  1  2
# 0  7  2  2
# 1  9  5  1
# 2  2  6  5

# %% [markdown]
# <h1>Row or Column Wise Function Application:</h1><br>
# Arbitrary functions can be applied along the axes of a DataFrame or Panel using the <b>apply()</b> method, which, like the descriptive statistics methods, takes an optional axis argument. By default, the operation performs column wise, taking each column as an array-like.

# %%
df.apply(np.mean) #columnwise mean..
# Out:
# 0    6.000000
# 1    4.333333
# 2    2.666667
# dtype: float64

# %%
df.apply(np.mean,axis=1) #rowise mean...
# Out:
# 0    3.666667
# 1    5.000000
# 2    4.333333
# dtype: float64

# %%
df.apply(lambda x: x.max() - x.min()) # difference b/w min value of a column and max value of a column..
# Out:
# 0    7
# 1    4
# 2    4
# dtype: int64

# %% [markdown]
# <h1>Element Wise Function Application</h1><br>
# Not all functions can be vectorized (neither the NumPy arrays which return another array nor any value), the methods <b>applymap()</b> on DataFrame and analogously <b>map()</b> on Series accept any Python function taking a single value and returning a single value.

# %%
df.applymap(lambda x:x*100)
# Out:
#      0    1    2
# 0  700  200  200
# 1  900  500  100
# 2  200  600  500

# %%
df[0].map(lambda x:x*100)
# Out:
# 0    700
# 1    900
# 2    200
# Name: 0, dtype: int64

# %% [markdown]
# <b><i>Reindexing, Renaming and iterating...</i></b>

# %%
df=pd.DataFrame(np.identity(3,dtype=int))

df2=pd.DataFrame(np.eye(3,4,k=0,dtype=int))
print(df)
df2
# Out:
#    0  1  2
# 0  1  0  0
# 1  0  1  0
# 2  0  0  1
#    0  1  2  3
# 0  1  0  0  0
# 1  0  1  0  0
# 2  0  0  1  0

# %%
df.reindex_like(df2)
# Out:
#    0  1  2   3
# 0  1  0  0 NaN
# 1  0  1  0 NaN
# 2  0  0  1 NaN

# %%
df.reindex_like(df2,method='ffill')
# Out:
#    0  1  2  3
# 0  1  0  0  0
# 1  0  1  0  0
# 2  0  0  1  1

# %%
df=df.rename(columns={0:'i',1:'ii',2:'iii',3:'iv'},index={0:"row1",1:"row2",2:"row3"})
df
# Out:
#       i  ii  iii
# row1  1   0    0
# row2  0   1    0
# row3  0   0    1

# %%
for key,value in df.iteritems():
    print(key,value)
# Out:
# i row1    1
# row2    0
# row3    0
# Name: i, dtype: int32
# ii row1    0
# row2    1
# row3    0
# Name: ii, dtype: int32
# iii row1    0
# row2    0
# row3    1
# Name: iii, dtype: int32

# %%
for key,value in df.iterrows():
    print(key,value)
# Out:
# row1 i      1
# ii     0
# iii    0
# Name: row1, dtype: int32
# row2 i      0
# ii     1
# iii    0
# Name: row2, dtype: int32
# row3 i      0
# ii     0
# iii    1
# Name: row3, dtype: int32

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index='row1', i=1, ii=0, iii=0)
# Pandas(Index='row2', i=0, ii=1, iii=0)
# Pandas(Index='row3', i=0, ii=0, iii=1)

# %% [markdown]
# <h2>Sorting:
#    </h2>
# There are two kinds of sorting available in Pandas. They are :
#
# By label
# By Actual Value
# <ul>
#     <li><b>By Label</b></li>
# Using the <b>sort_index()</b> method, by passing the axis arguments and the order of sorting, DataFrame can be sorted. By default, sorting is done on row labels in ascending order.

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

unsorted_df.sort_index()
# Out:
#        col2      col1
# 0 -0.488665  1.665704
# 1 -1.012924  0.039062
# 2  0.395421  1.605605
# 3 -0.555867 -1.473315
# 4 -1.869384  0.209380
# 5 -2.393794  0.634183
# 6  0.720970 -0.623988
# 7 -0.800314 -0.388323
# 8 -0.903794  0.065797
# 9 -0.439115  0.342959

# %%
unsorted_df.sort_index(ascending=False)
# Out:
#        col2      col1
# 9 -0.439115  0.342959
# 8 -0.903794  0.065797
# 7 -0.800314 -0.388323
# 6  0.720970 -0.623988
# 5 -2.393794  0.634183
# 4 -1.869384  0.209380
# 3 -0.555867 -1.473315
# 2  0.395421  1.605605
# 1 -1.012924  0.039062
# 0 -0.488665  1.665704

# %%
unsorted_df.sort_index(axis=1)
# Out:
#        col1      col2
# 1  0.039062 -1.012924
# 4  0.209380 -1.869384
# 6 -0.623988  0.720970
# 2  1.605605  0.395421
# 3 -1.473315 -0.555867
# 5  0.634183 -2.393794
# 9  0.342959 -0.439115
# 8  0.065797 -0.903794
# 0  1.665704 -0.488665
# 7 -0.388323 -0.800314

# %% [markdown]
# <li><b>By Value</b></li>
# Like index sorting, <b>sort_values()</b> is the method for sorting by values. It accepts a 'by' argument which will use the column name of the DataFrame with which the values are to be sorted.</ul>

# %%
unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})
unsorted_df.sort_values(by='col1')
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1

# %%
unsorted_df.sort_values(by=['col1','col2'])
# Out:
#    col1  col2
# 2     1     2
# 1     1     3
# 3     1     4
# 0     2     1

# %%
 unsorted_df.sort_values(by='col1' ,kind='mergesort')
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1

# %% [markdown]
# The Pandas I/O API is a set of top level reader functions accessed like <b>pd.read_csv() </b>that generally return a Pandas object.
#
# The two workhorse functions for reading text files (or the flat files) are <b>read_csv() </b>and<b> read_table()</b>. They both use the same parsing code to intelligently convert tabular data into a DataFrame object −

# %%
data=pd.read_csv("terrorismData.csv")
data.head(2)
data2=data.copy()
data2
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
len(data['Day'][10:21]) #attacks between day 10 and 20
# Out:
# 11

# %%
max(data['Killed'])
# Out:
# 1570.0

# %%
data[data['Killed']==1570.0][['Target','Country']]   #SELECT Target,Country FROM data WHERE 'Killed'= 1570.0;
# Out:
#           Target Country
# 133518  Soldiers    Iraq

# %%
k=data[data['Month']==1]
len(k[k['Year']==2010])    # No. of attacks frm 1 jan2010 to 31st jan 2010 (inc both limits)
# Out:
# 278

# %%
k=data[data['Month']>=5]
k[k['Month']<7]
k['Killed'].fillna(0)
k['Wounded'].fillna(0)
a=pd.Series(k['Killed']+k['Wounded'])

Ans=pd.DataFrame([a,k['City'],k['Group']],index=["Casualities","City","Group"]).T
Ans
# Out:
#        Casualities           City                                       Group
# 0                1  Santo Domingo                                      MANO-D
# 244              0         Boston                          Black Nationalists
# 245              1    Rio Piedras                   Puerto Rican Nationalists
# 246              0  New York City                         Left-Wing Militants
# 247              0    Greencastle                            Student Radicals
# ...            ...            ...                                         ...
# 181686           3  Ceelka Geelow                                  Al-Shabaab
# 181687           9         Jableh                           Muslim extremists
# 181688           0       Kubentog  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689           0         Imphal                                     Unknown
# 181690           0  Cotabato City                                     Unknown
#
# [122447 rows x 3 columns]

# %%
data2=pd.read_csv("iris.csv")
data2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
print(len(data2[data2['variety']=='Setosa']),len(data2[data2['variety']=='Virginica']),len(data2[data2['variety']=='Versicolor']))
# Out:
# 50 50 50

# %%
df=data2.copy()
df.drop(1,inplace=True)#by label
df.drop(df.index[1],inplace=True)#by position
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [148 rows x 5 columns]

# %%
#find summary of data where variety is Sentosa...
data2[data2.variety=='Setosa'].describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
df2=data2.copy()
def change(s):
    if(s=='Setosa'):
        return 0
    elif(s=='Virginica'):
        return 1
    else:
        return 2
df2['flower_type']=df2['variety'].apply(change)
df2.drop('variety',axis=1,inplace=True)
df2.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  flower_type
# 0           5.1          3.5           1.4          0.2            0
# 1           4.9          3.0           1.4          0.2            0
# 2           4.7          3.2           1.3          0.2            0
# 3           4.6          3.1           1.5          0.2            0
# 4           5.0          3.6           1.4          0.2            0
