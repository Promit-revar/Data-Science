# %%
import requests as req
from bs4 import BeautifulSoup

# %%
res=req.request('GET',"https://www.bajajfinserv.in/#more")
res.status_code
# Out:
# 200

# %%
data=res.text

# %%
html=BeautifulSoup(data,"html.parser")
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge, IE=EmulateIE7" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/sites/bajaj/15Sep2017/images/baflicon.ico" rel="SHORTCUT ICON"/>
#   <link href="https://www.bajajfinserv.in/" hreflang="en-in" rel="alternate"/>
#   <link href="https://www.bajajfinserv.in/hindi/" hreflang="hi-in" rel="alternate"/>
#   <link href="https://www.bajajfinserv.in/tamil/" hreflang="ta-in" rel="alternate"/>
#   <link href="https://www.bajajfinserv.in/kannada/" hreflang="kn-in" rel="alternate"/>
#   <link href="https://www.bajajfinserv.in/malayalam/" hreflang="ml-in" rel="alternate"/>
# ...
